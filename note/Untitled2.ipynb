# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np

# %%
women=pd.read_csv("women.csv")

# %%
women
# Out:
#     height  weight
# 0       58     115
# 1       59     117
# 2       60     120
# 3       61     123
# 4       62     126
# 5       63     129
# 6       64     132
# 7       65     135
# 8       66     139
# 9       67     142
# 10      68     146
# 11      69     150
# 12      70     154
# 13      71     159
# 14      72     164

# %%
plt.boxplot(women['weight'])
plt.show()
np.min(women['weight'])
# Out:
# 115

# %%
np.max(women['weight'])
# Out:
# 164

# %%
np.median(women['weight'])
# Out:
# 135.0

# %%
samples_1=np.random.normal(loc=1,scale=0.5,size=10000)
samples_2=np.random.standard_t(df=10,size=10000)

# %%
help(np.random.normal)
# Out:
# Help on built-in function normal:
#
# normal(...) method of mtrand.RandomState instance
#     normal(loc=0.0, scale=1.0, size=None)
#
#     Draw random samples from a normal (Gaussian) distribution.
#
#     The probability density function of the normal distribution, first
#     derived by De Moivre and 200 years later by both Gauss and Laplace
#     independently [2]_, is often called the bell curve because of
#     its characteristic shape (see the example below).
#
#     The normal distributions occurs often in nature.  For example, it
#     describes the commonly occurring distribution of samples influenced
#     by a large number of tiny, random disturbances, each with its own
#     unique distribution [2]_.
#
#     Parameters
#     ----------
#     loc : float or array_like of floats
#         Mean ("centre") of the distribution.
#     scale : float or array_like of floats
#         Standard deviation (spread or "width") of the distribution.
# ...

# %%
bins=np.linspace(-3,3,25)

# %%
plt.hist(samples_1,bins=bins,alpha=0.5,label='samples 1',ec='black',color='red')

plt.hist(samples_2,bins=bins,alpha=0.7,label='samples 2',ec='red',color='green')
plt.legend(loc='upper_left')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\legend.py:497: UserWarning: Unrecognized location "upper_left". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
plt.scatter(samples_1,samples_2,alpha=0.05,c='y')

# %%
x=np.arange(120)
y=np.cos(x)
z=np.cos(np.pi * x)
w=2 * np.cos(x/np.pi)

# %%
fig1=plt.figure()
ax1=fig1.add_subplot(2,1,1)
ax1.plot(x,y,color='blue')
ax1.plot(x,w,color='green')
ax1.set_ylim([-2,2])
# Out:
# (-2, 2)

# %%
fig1=plt.figure()
ax2=fig1.add_subplot(212)
ax2.plot(x,z,color='y')
ax2.set_ylim([-2,2])
# Out:
# (-2, 2)

# %%
fig1=plt.figure()
ax1=fig1.add_subplot(2,1,1)
ax1.plot(x,y,color='blue')
ax1.plot(x,w,color='green')
ax1.set_ylim([-2,2])


ax2=fig1.add_subplot(212)
ax2.plot(x,z,color='y')
ax2.set_ylim([-2,2])
# Out:
# (-2, 2)

# %%
crime=pd.read_csv('samplecrime.csv')
crime
# Out:
#       IncidntNum        Category  \
# 0      140009459           ARSON
# 1      140042001           FRAUD
# 2      140071185   VEHICLE THEFT
# 3      140094892         ASSAULT
# 4      140096371         ROBBERY
# 5      140127540         ASSAULT
# 6      150017276    NON-CRIMINAL
# 7      150007374  OTHER OFFENSES
# 8      150017787  OTHER OFFENSES
# 9      140152274         ASSAULT
# 10     146040665    NON-CRIMINAL
# 11     140191006   LARCENY/THEFT
# 12     146045734    NON-CRIMINAL
# 13     146046704    NON-CRIMINAL
# 14     146048368   LARCENY/THEFT
# 15     140195020    NON-CRIMINAL
# 16     146054729    NON-CRIMINAL
# 17     146052319    NON-CRIMINAL
# 18     146057585    NON-CRIMINAL
# 19     140258377   LARCENY/THEFT
# 20     146052773    NON-CRIMINAL
# 21     150021346  OTHER OFFENSES
# 22     140281500   LARCENY/THEFT
# 23     150022297    NON-CRIMINAL
# 24     150011660         ROBBERY
# 25     150022065    NON-CRIMINAL
# 26     140323130    NON-CRIMINAL
# ...

# %%
type(crime)
# Out:
# pandas.core.frame.DataFrame

# %%
crime.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# dtype: object

# %%
crime_sorted=crime.sort_values("Category",ascending=True)
crime_sorted
# Out:
#      IncidntNum     Category  \
# 0     140009459        ARSON
# 39    140504120        ARSON
# 244   150115585        ARSON
# 421   140002196        ARSON
# 211   140628491        ARSON
# 75    150058822        ARSON
# 311   141099093        ARSON
# 181   140518143        ARSON
# 122   150046253      ASSAULT
# 357   150024986      ASSAULT
# 124   140167411      ASSAULT
# 355   150022720      ASSAULT
# 351   140652650      ASSAULT
# 127   140179030      ASSAULT
# 128   140199890      ASSAULT
# 94    150002926      ASSAULT
# 130   140230284      ASSAULT
# 335   141072839      ASSAULT
# 333   140914193      ASSAULT
# 133   150104782      ASSAULT
# 331   150023988      ASSAULT
# 89    150072496      ASSAULT
# 136   150106001      ASSAULT
# 362   150024992      ASSAULT
# 346   150024845      ASSAULT
# 384   140007168      ASSAULT
# 118   150045675      ASSAULT
# 458   140003520      ASSAULT
# 433   140003423      ASSAULT
# 99    140036521      ASSAULT
# ..          ...          ...
# ...

# %%
crime_sorted=crime.sort_values("Category",ascending=False)
crime_sorted
# Out:
#      IncidntNum     Category                                         Descript  \
# 750   140019094  WEAPON LAWS        LOITERING WHILE CARRYING CONCEALED WEAPON
# 880   140022746  WEAPON LAWS                      CARRYING A CONCEALED WEAPON
# 881   140022746  WEAPON LAWS                           POSS OF LOADED FIREARM
# 395   140000275  WEAPON LAWS             DISCHARGE FIREARM WITHIN CITY LIMITS
# 506   140009114  WEAPON LAWS   EXHIBITING DEADLY WEAPON IN A THREATING MANNER
# 59    150042160  WEAPON LAWS  POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN
# 708   140007243  WEAPON LAWS       DISCHARGE FIREARM AT AN INHABITED DWELLING
# 464   140005667     WARRANTS                  ENROUTE TO OUTSIDE JURISDICTION
# 560   140009459     WARRANTS                                   WARRANT ARREST
# 79    140982388     WARRANTS                                   WARRANT ARREST
# 205   150018309     WARRANTS                                   WARRANT ARREST
# ...

# %%
count_category=crime['Category'].value_counts()
count_category
# Out:
# OTHER OFFENSES                 192
# LARCENY/THEFT                  190
# NON-CRIMINAL                   154
# ASSAULT                        124
# WARRANTS                        58
# DRUG/NARCOTIC                   48
# VEHICLE THEFT                   46
# ROBBERY                         40
# VANDALISM                       27
# SUSPICIOUS OCC                  23
# MISSING PERSON                  20
# FRAUD                           17
# DRUNKENNESS                     10
# ARSON                            8
# WEAPON LAWS                      7
# BURGLARY                         6
# SECONDARY CODES                  6
# RUNAWAY                          5
# FORGERY/COUNTERFEITING           4
# PROSTITUTION                     4
# KIDNAPPING                       4
# TRESPASS                         4
# DISORDERLY CONDUCT               3
# LIQUOR LAWS                      2
# DRIVING UNDER THE INFLUENCE      2
# RECOVERED VEHICLE                1
# FAMILY OFFENSES                  1
# ...

# %%
df=pd.DataFrame(count_category)
df
# Out:
#                              Category
# OTHER OFFENSES                    192
# LARCENY/THEFT                     190
# NON-CRIMINAL                      154
# ASSAULT                           124
# WARRANTS                           58
# DRUG/NARCOTIC                      48
# VEHICLE THEFT                      46
# ROBBERY                            40
# VANDALISM                          27
# SUSPICIOUS OCC                     23
# MISSING PERSON                     20
# FRAUD                              17
# DRUNKENNESS                        10
# ARSON                               8
# WEAPON LAWS                         7
# BURGLARY                            6
# SECONDARY CODES                     6
# RUNAWAY                             5
# FORGERY/COUNTERFEITING              4
# PROSTITUTION                        4
# KIDNAPPING                          4
# TRESPASS                            4
# DISORDERLY CONDUCT                  3
# LIQUOR LAWS                         2
# ...

# %%
df1=df.reset_index()
df1
# Out:
#                           index  Category
# 0                OTHER OFFENSES       192
# 1                 LARCENY/THEFT       190
# 2                  NON-CRIMINAL       154
# 3                       ASSAULT       124
# 4                      WARRANTS        58
# 5                 DRUG/NARCOTIC        48
# 6                 VEHICLE THEFT        46
# 7                       ROBBERY        40
# 8                     VANDALISM        27
# 9                SUSPICIOUS OCC        23
# 10               MISSING PERSON        20
# 11                        FRAUD        17
# 12                  DRUNKENNESS        10
# 13                        ARSON         8
# 14                  WEAPON LAWS         7
# 15                     BURGLARY         6
# 16              SECONDARY CODES         6
# 17                      RUNAWAY         5
# 18       FORGERY/COUNTERFEITING         4
# 19                 PROSTITUTION         4
# 20                   KIDNAPPING         4
# ...

# %%
df1.columns=['Category','Frequency']
df1
sample=df1.head()
sample
# Out:
#          Category  Frequency
# 0  OTHER OFFENSES        192
# 1   LARCENY/THEFT        190
# 2    NON-CRIMINAL        154
# 3         ASSAULT        124
# 4        WARRANTS         58

# %%
plt.bar(sample['Category'],sample['Frequency'],color='black')
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.title("Frequency of category f crime")
plt.show()

# %%
count_days=crime['DayOfWeek'].value_counts()
count_days
# Out:
# Wednesday    209
# Thursday     184
# Friday       162
# Sunday       126
# Saturday     111
# Monday       110
# Tuesday      104
# Name: DayOfWeek, dtype: int64

# %%
df=pd.DataFrame(count_days)
df
# Out:
#            DayOfWeek
# Wednesday        209
# Thursday         184
# Friday           162
# Sunday           126
# Saturday         111
# Monday           110
# Tuesday          104

# %%
df1=df.reset_index()
df1
# Out:
#        index  DayOfWeek
# 0  Wednesday        209
# 1   Thursday        184
# 2     Friday        162
# 3     Sunday        126
# 4   Saturday        111
# 5     Monday        110
# 6    Tuesday        104

# %%
df1.columns=['Days','Frequency']
df1
sample=df1.head()
sample
# Out:
#         Days  Frequency
# 0  Wednesday        209
# 1   Thursday        184
# 2     Friday        162
# 3     Sunday        126
# 4   Saturday        111

# %%
plt.bar(sample['Days'],sample['Frequency'],color='black')
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.title("Frequency of days of crime")
plt.show()

# %%
count_ros=crime['Resolution'].value_counts()
count_ros
# Out:
# NONE                            615
# ARREST, BOOKED                  209
# ARREST, CITED                   128
# PSYCHOPATHIC CASE                19
# UNFOUNDED                        15
# LOCATED                          10
# EXCEPTIONAL CLEARANCE             3
# JUVENILE CITED                    3
# JUVENILE BOOKED                   2
# PROSECUTED BY OUTSIDE AGENCY      1
# NOT PROSECUTED                    1
# Name: Resolution, dtype: int64

# %%
ros=pd.DataFrame(count_ros)
ros
# Out:
#                               Resolution
# NONE                                 615
# ARREST, BOOKED                       209
# ARREST, CITED                        128
# PSYCHOPATHIC CASE                     19
# UNFOUNDED                             15
# LOCATED                               10
# EXCEPTIONAL CLEARANCE                  3
# JUVENILE CITED                         3
# JUVENILE BOOKED                        2
# PROSECUTED BY OUTSIDE AGENCY           1
# NOT PROSECUTED                         1

# %%
af1=ros.reset_index()
af1
# Out:
#                            index  Resolution
# 0                           NONE         615
# 1                 ARREST, BOOKED         209
# 2                  ARREST, CITED         128
# 3              PSYCHOPATHIC CASE          19
# 4                      UNFOUNDED          15
# 5                        LOCATED          10
# 6          EXCEPTIONAL CLEARANCE           3
# 7                 JUVENILE CITED           3
# 8                JUVENILE BOOKED           2
# 9   PROSECUTED BY OUTSIDE AGENCY           1
# 10                NOT PROSECUTED           1

# %%
x=["Arrest","Pending"]
x
# Out:
# ['Arrest', 'Pending']

# %%
y=[sum(af1.iloc[[1,2]1])+sum(af1.iloc[2:17,1]+af1.iloc[0,1])
